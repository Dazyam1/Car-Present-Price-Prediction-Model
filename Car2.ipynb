# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import pickle
import warnings
warnings.filterwarnings ('ignore')

# %%
df = pd.read_csv('car data.csv')
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.Owner.unique()
# Out:
# array([0, 1, 3], dtype=int64)

# %%
df.shape
# Out:
# (301, 9)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df['Owner'].value_counts()
# Out:
# Owner
# 0    290
# 1     10
# 3      1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
# Hash function to map categories to a fixed number of bins
def hash_encode(value, num_bins):
    return hash(value) % num_bins

# Number of bins to hash into (e.g., 10 bins)
num_bins = 10

# Applying the hash function to the 'car_name' column
df['Car_Name'] = df['Car_Name'].apply(lambda x: hash_encode(x, num_bins))

fuel_type_map = {'Petrol': 0, 'Diesel': 1, 'CNG': 2}
seller_type_map = {'Dealer': 0, 'Individual': 1}
transmission_map = {'Manual': 0, 'Automatic': 1}

# Apply the mappings to the corresponding columns
# df['Car_Name'] = df['Car_Name'].map(car_name_map)
df['Fuel_Type'] = df['Fuel_Type'].map(fuel_type_map)
df['Seller_Type'] = df['Seller_Type'].map(seller_type_map)
df['Transmission'] = df['Transmission'].map(transmission_map)

# %%
df.head()
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0         1  2014           3.35           5.59       27000          0
# 1         7  2013           4.75           9.54       43000          1
# 2         8  2017           7.25           9.85        6900          0
# 3         6  2011           2.85           4.15        5200          0
# 4         3  2014           4.60           6.87       42450          1
#
#    Seller_Type  Transmission  Owner
# 0            0             0      0
# 1            0             0      0
# 2            0             0      0
# 3            0             0      0
# 4            0             0      0

# %%
target = 'Selling_Price'
y = df[target]
df.drop(columns = ['Selling_Price'], inplace = True)
features = list(df.columns)
x = df[features]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split (x, y, test_size = 0.2, random_state = 4)

# %%
print(x.shape,y.shape)
# Out:
# (301, 8) (301,)

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression ()
lr.fit (x_train, y_train)

from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor ()
rf.fit (x_train, y_train)

from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor ()
gbr.fit (x_train, y_train)

from xgboost import XGBRegressor
xg = XGBRegressor ()
xg.fit (x_train, y_train)

from sklearn.tree import DecisionTreeRegressor
tree = DecisionTreeRegressor()
tree.fit (x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
print ('Logistic Regression Train Score is', lr.score (x_train, y_train)* 100)
print ('Random Forest Classifier Train Score is', rf.score (x_train, y_train)* 100)
print ('Gradient Boosting Classifier Train Score is', gbr.score (x_train, y_train)* 100)
print ('XGBoost Classifier Train Score is', xg.score (x_train, y_train)* 100)
print ('Decision Tree Classifier Train Score is', tree.score (x_train, y_train)* 100)
# Out:
# Logistic Regression Train Score is 88.70461880613419
# Random Forest Classifier Train Score is 98.56552456254057
# Gradient Boosting Classifier Train Score is 99.57106407512893
# XGBoost Classifier Train Score is 99.99984308763895
# Decision Tree Classifier Train Score is 100.0

# %%
print ('Logistic Classifier Test Score is', lr.score (x_test, y_test) * 100)
print ('Random Forest Classifier Test Score is', rf.score (x_test, y_test)* 100)
print ('Gradient Boosting Classifier Test Score is', gbr.score (x_test, y_test)* 100)
print ('XGBoost Classifier Test Score is', xg.score (x_test, y_test)* 100)
print ('Decision Tree Classifier Test Score is', tree.score (x_test, y_test)* 100)
# Out:
# Logistic Classifier Test Score is 84.57820621997676
# Random Forest Classifier Test Score is 90.82811738659231
# Gradient Boosting Classifier Test Score is 92.00745020768687
# XGBoost Classifier Test Score is 89.94304639777542
# Decision Tree Classifier Test Score is 90.90237357805734

# %%
# joblib.dump (gbr, 'Car Prediction Model 1.pkl')

with open('Car Prediction Model 1.sav', 'wb') as file:
    pickle.dump(gbr, file)

# %%
print(type(gbr))
# Out:
# <class 'sklearn.ensemble._gb.GradientBoostingRegressor'>
